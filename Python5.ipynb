# %%
a=2
b=3
if(a>b):
    print("a is greater")
else:
    print("b is greater")
# Out:
# b is greater

# %%
a=2
b=1
if(a>b):
    print("a is greater")
# Out:
# a is greater

# %%
a=5
print(a)
# Out:
# 5

# %%
a=5
print(a)
print(type(a))
# Out:
# 5
# <class 'int'>

# %%
a=5.0
print(a)
print(type(a))
# Out:
# 5.0
# <class 'float'>

# %%
a=5.0
b="bitty"
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 5.0
# bitty
# <class 'float'>
# <class 'str'>

# %%
a=5.0
b="bitty"
c=True
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 5.0
# bitty
# True
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a=5.0
b="bitty"
c=True
d=2+4j
print(a)
print(b)
print(c)
print(d)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 5.0
# bitty
# True
# (2+4j)
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
a=5.0
b="bitty"
c=True
d=2+4j
e=None
print(a)
print(b)
print(c)
print(d)
print(e)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# 5.0
# bitty
# True
# (2+4j)
# None
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>
# <class 'NoneType'>

# %%
cars=["BMW","Suzuki","Volvo","Honda"]
print(cars)
print(type(cars))
# Out:
# ['BMW', 'Suzuki', 'Volvo', 'Honda']
# <class 'list'>

# %%
cars=["BMW","Suzuki","Volvo","Honda","Honda"]
print(cars)
print(type(cars))
print(cars[0])
# Out:
# ['BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda']
# <class 'list'>
# BMW

# %%
cars=["BMW","Suzuki","Volvo","Honda","Honda"]
print(cars)
print(type(cars))
print(cars[0-2])
# Out:
# ['BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda']
# <class 'list'>
# Honda

# %%
cars=["BMW","Suzuki","Volvo","Honda","Honda"]
print(cars)
print(type(cars))
print(cars[0:2])
cars.append("Merecedez")
print(cars)
# Out:
# ['BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda']
# <class 'list'>
# ['BMW', 'Suzuki']
# ['BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda', 'Merecedez']

# %%
cars=("BMW","Suzuki","Volvo","Honda","Honda")
print(cars)
print(type(cars))
# Out:
# ('BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda')
# <class 'tuple'>

# %%
cars=("BMW","Suzuki","Volvo","Honda","Honda")
print(cars)
print(type(cars))
cars.append("Merecedez")
# Out:
# ('BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda')
# <class 'tuple'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13008/71461828.py in <module>
#       2 print(cars)
#       3 print(type(cars))
# ----> 4 cars.append("Merecedez")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
cars=("BMW","Suzuki","Volvo","Honda","Honda")
print(cars)
print(type(cars))
print(cars[0])
# Out:
# ('BMW', 'Suzuki', 'Volvo', 'Honda', 'Honda')
# <class 'tuple'>
# BMW

# %%
cars={1,5,10,4,3,11,9,2,20}
print(cars)
# Out:
# {1, 2, 3, 4, 5, 9, 10, 11, 20}

# %%
cars={1,5,10,4,3,11,9,2,20,5}
print(cars)
print(type(cars))
# Out:
# {1, 2, 3, 4, 5, 9, 10, 11, 20}
# <class 'set'>

# %%
cars={"BMW","Suzuki","Volvo","Honda","Honda"}
print(cars)
# Out:
# {'Volvo', 'Suzuki', 'BMW', 'Honda'}

# %%
fruits={"Tropical":["Apple","Grapes","Orange"],"Rain":["150","80","70"]}
print(fruits)
print(type(fruits))
# Out:
# {'Tropical': ['Apple', 'Grapes', 'Orange'], 'Rain': ['150', '80', '70']}
# <class 'dict'>

# %%
fruits={"Tropical":["Apple","Grapes","Orange"],"Rain":["150","80","70"]}
print(fruits)
print(type(fruits))
print(fruits)
# Out:
# {'Tropical': ['Apple', 'Grapes', 'Orange'], 'Rain': ['150', '80', '70']}
# <class 'dict'>
# {'Tropical': ['Apple', 'Grapes', 'Orange'], 'Rain': ['150', '80', '70']}
