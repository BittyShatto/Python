# %%
a =["bitty","shatto","alvi"]
print(a[1])
# Out:
# shatto

# %%
a =["bitty","shatto","alvi"]
a.append("bind")
print(a)
# Out:
# ['bitty', 'shatto', 'alvi', 'bind']

# %%
a[1:4]
# Out:
# ['shatto', 'alvi', 'bind']

# %%
a =["bitty","shatto","alvi"]
a.insert(1,"rain")
print(a)
# Out:
# ['bitty', 'rain', 'shatto', 'alvi']

# %%
a =["bitty","shatto","alvi"]
a.insert(1,"rain")
a.insert(2,"amee")
print(a)
# Out:
# ['bitty', 'rain', 'amee', 'shatto', 'alvi']

# %%
b = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
b.extend(tropical)
print(b)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
c=['a','b','c','d',1,2,3]
len(c)
# Out:
# 7

# %%
a =["bitty","shatto","alvi"]
a.clear()
print(a)
# Out:
# []

# %%
a =["bitty","shatto","alvi"]
a.pop()
print(a)
# Out:
# ['bitty', 'shatto']

# %%
list = ["apple", "banana", "cherry"]
for x in list:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
list = ["apple", "banana", "cherry"]
for i in range(len(list)):
  print(list[i])
# Out:
# apple
# banana
# cherry

# %%
list = ["apple", "banana", "cherry"]
i = 0
while i < len(list):
  print(list[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
list=["apple","banana","grape"]
i=0
while i < len(list):
    print(list[i])
    i=i+1
# Out:
# apple
# banana
# grape

# %%
list=["apple","banana","grape"]
[print(x) for x in list]
# Out:
# apple
# banana
# grape
# [None, None, None]

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
a = ["orange", "mango", "kiwi", "pineapple", "banana"]
a.sort()
print(a)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
a = ["Orange", "mango", "kiwi", "Pineapple", "banana"]
a.sort(reverse=True)
print(a)
# Out:
# ['mango', 'kiwi', 'banana', 'Pineapple', 'Orange']

# %%
def my_function():
  print("Hello bit")

my_function()
# Out:
# Hello bit

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil", "Refsnes")
my_function("bitty", "shatto")
# Out:
# Emil Refsnes
# bitty shatto

# %%
def my_function(*kids):
  print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %%
def my_function(child3, child2, child1):
  print("The youngest child is " + child2)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")
# Out:
# The youngest child is Tobias

# %%
def my_function(**kid):
  print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %%
def my_function(country = "India"):
  print("I am from " + country)

my_function("Italy")
my_function("Norway")
my_function()
my_function("Brazil")
# Out:
# I am from Italy
# I am from Norway
# I am from India
# I am from Brazil

# %%
def function(food):
  for x in food:
    print(x)

fruits = ["grapes", "banana", "strawberry"]

function(fruits)
# Out:
# grapes
# banana
# strawberry

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("Bitty", "Shatto")
x.printname()
# Out:
# Bitty Shatto

# %%
class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

x = Student("Bitty", "Shatto", 2019)

# %%
mystr = "banana"
myit = iter(mystr)

print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a

# %%
mytuple = ("apple", "banana", "cherry")

for x in mytuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
x = "Hello World!"

print(len(x))
# Out:
# 12

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(len(thisdict))
# Out:
# 3

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       
boat1 = Boat("Ibiza", "Touring 20") 
plane1 = Plane("Boeing", "747")     

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang") 
boat1 = Boat("Ibiza", "Touring 20") 
plane1 = Plane("Boeing", "747") 

for x in (car1, boat1, plane1):
  print(x.brand)
  print(x.model)
  x.move()
# Out:
# Ford
# Mustang
# Move!
# Ibiza
# Touring 20
# Sail!
# Boeing
# 747
# Fly!
