# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
iris=datasets.load_iris()
print(iris)
df=pd.DataFrame(data=iris)

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

df = pandas.read_csv("data.csv")

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("decision_tree.csv")

d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Go']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(111.60000000000001, 190.26, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(55.800000000000004, 135.9, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(167.4, 135.9, 'Experience <= 9.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(111.60000000000001, 81.53999999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(223.20000000000002, 81.53999999999999, 'Experience <= 11.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(167.4, 27.180000000000007, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(279.0, 27.180000000000007, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("decision_tree.csv")

d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Go']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)#capital X-combination of more than one variable

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(133.92000000000002, 195.696, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(66.96000000000001, 152.208, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(200.88000000000002, 152.208, 'Nationality <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(133.92000000000002, 108.72, 'Age <= 35.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(66.96000000000001, 65.232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(200.88000000000002, 65.232, 'Age <= 40.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(133.92000000000002, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(267.84000000000003, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(267.84000000000003, 108.72, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
import pandas as pd

df = pd.read_csv('decision_tree.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          13 non-null     int64
#  1   Experience   13 non-null     int64
#  2   Rank         13 non-null     int64
#  3   Nationality  13 non-null     object
#  4   Go           13 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 648.0+ bytes
# None

# %%
import pandas as pd

df = pd.read_csv('decision_tree.csv')

print(df.to_string())
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
import pandas as pd

df = pd.read_csv('decision_tree.csv') #complete data

print(df.to_string())
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# C:\Users\cclab25\AppData\Local\Temp/ipykernel_13536/1220820273.py:13: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\programdata\anaconda3\lib\site-packages (0.0.post9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

plt.scatter(x, y)
plt.show()
# Out:
# C:\Users\cclab25\AppData\Local\Temp/ipykernel_10744/2254930646.py:8: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
