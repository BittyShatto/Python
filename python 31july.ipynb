# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
        
    def printname(self):
        print(self.firstname,self.lastname)
        
x = Person("Bitty","Shatto")
x.printname()
# Out:
# Bitty Shatto

# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
        
    def printname(self):
        print(self.firstname,self.lastname)
        
class Student(Person):
    pass
          
x = Person("Bitty","Shatto")
x.printname()
# Out:
# Bitty Shatto

# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
        
    def printname(self):
        print(self.firstname,self.lastname)
        
class Student(Person):
    pass
          
x = Person("Bitty","Shatto")
x.printname()

x = Student("Jitto","Jose")
x.printname()
# Out:
# Bitty Shatto
# Jitto Jose

# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
        
    def printname(self):
        print(self.firstname,self.lastname)
        
class Student(Person):
    def __init__(self,fname,lname):
        Person.__init__(self,fname,lname)
          
x = Person("Bitty","Shatto")
x.printname()

x = Student("Shatto","Jose")
x.printname()
# Out:
# Bitty Shatto
# Shatto Jose

# %%
class Person:
    def __init__(self,fname,lname):
        self.firstname = fname
        self.lastname = lname
        
    def printname(self):
        print(self.firstname,self.lastname)
        
class Student(Person):
    def __init__(self,fname,lname):
        Person.__init__(self,fname,lname)
               
x = Person("Bitty","Shatto")
x.printname()

x = Student("Shitto","Jose")
x.printname()
# Out:
# Bitty Shatto
# Shitto Jose

# %%
class School:
  def __init__(self,teachers,students):
    self.teachers = teachers
    self.students = students
    
  def move(self):
    print("Study!!")
    
class College:
  def __init__(self, lectures,students):
    self.lectures = lectures
    self.students = students

  def move(self):
    print("Study!!")
    
class Job:
  def __init__(self,Manager,employees):
    self.Manager = Manager
    self.employees= employees

  def move(self):
    print("Hardwork!!")
    
School1 =School("Ritta","anu")       
College1 = College("Suja","Appu") 
Job1 = Job("Albert","Rain") 

for x in (School1,College1,Job1):
  x.move()
# Out:
# Study!!
# Study!!
# Hardwork!!

# %%
def mywork():
  x = 500
  print(x)

mywork()
# Out:
# 500

# %%
import json

x =  '{ "name":"Bitty", "age":22, "city":"Thrissur"}'
y = json.loads(x)
print(y["city"])
print(type(y))
# Out:
# Thrissur
# <class 'dict'>

# %%
import json


x = {
  "name": "Bitty",
  "age": 22,
  "city": "Thrissur"
}

y = json.dumps(x)
print(type(y))
print(y)
# Out:
# <class 'str'>
# {"name": "Bitty", "age": 22, "city": "Thrissur"}

# %%
f = open("demofile.txt", "x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4376/918175314.py in <module>
# ----> 1 f = open("demofile.txt", "x")
#
# FileExistsError: [Errno 17] File exists: 'demofile.txt'

# %%
f = open("demofile.txt", "r")
print(f.read())
# Out:
# Hello! Welcome to demofile.txt
# This file is for testing purposes.
# Good Luck!

# %%
f = open("demofile.txt", "r")
print(f.read(5))
# Out:
# Hello

# %%
f = open("D:\\myfiles\welcome.txt", "x")
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4376/3492119728.py in <module>
# ----> 1 f = open("D:\\myfiles\welcome.txt", "x")
#       2 print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\myfiles\\welcome.txt'
